# %%
# !ls ../../samples/


# https://cktt-cdr.tdtu.edu.vn/chuandaura
# Out:
# sample.txt  tdt_records.jsonl

# %%
import pandas as pd

PATH = "../../samples"

df = pd.read_json(f"{PATH}/tdt_records.jsonl", lines=True)

test_df = df.sample(n=20)
test_df.shape
test_df
# Out:
#                                                      url  \
# 5197   https://international.tdtu.edu.vn/en/news/2023...
# 48207  https://lib.tdtu.edu.vn/library-calendar/floor...
# 7545   https://enlabsafe.tdtu.edu.vn/en/news/2022/exc...
# 2375       https://student.tdtu.edu.vn/taxonomy/term/485
# 4821   https://grad.tdtu.edu.vn/en/news/2019/opening-...
# 25982         https://vfis.tdtu.edu.vn/index.php/node/46
# 50250  https://lib.tdtu.edu.vn/vi/library-calendar/la...
# 47399  https://lib.tdtu.edu.vn/library-calendar/baolo...
# 18291  https://feee.tdtu.edu.vn/en/publications/2021/...
# 8246         https://lib.tdtu.edu.vn/news-events?page=31
# 1872              https://student.tdtu.edu.vn/index.php/
# 23216  https://feee.tdtu.edu.vn/en/news/news-events/g...
# 27712  https://vfis.tdtu.edu.vn/news/2022-05/vfis-sto...
# 19256  https://it.tdtu.edu.vn/tuan-trien-lam-nghien-c...
# 44228  https://lib.tdtu.edu.vn/vi/library-calendar/la...
# ...

# %%
test_df
# Out:
#                                                      url  \
# 51613  https://lib.tdtu.edu.vn/library-calendar/nhatr...
# 51497  https://lib.tdtu.edu.vn/library-calendar/nhatr...
# 40222  https://lib.tdtu.edu.vn/library-calendar/floor...
# 42954  https://lib.tdtu.edu.vn/vi/library-calendar/la...
# 25020  https://vietnamesestudies.tdtu.edu.vn/index.ph...
# 29649  https://baoloc.tdtu.edu.vn/goc-kham-pha/kham-p...
# 48061  https://lib.tdtu.edu.vn/library-calendar/baolo...
# 22983  https://ssh.tdtu.edu.vn/en/vns/undergraduate/C...
# 28402  https://lib.tdtu.edu.vn/library-calendar/moonl...
# 31922        https://tdtu.edu.vn/en/news/students?page=9
# 12304            https://oer.tdtu.edu.vn/detail/?id=6789
# 10116  https://lib.tdtu.edu.vn/library-calendar/floor...
# 34775     https://clc.tdtu.edu.vn/taxonomy/term/177/feed
# 43143  https://lib.tdtu.edu.vn/vi/library-calendar/la...
# 24525  https://vietnamesestudies.tdtu.edu.vn/taxonomy...
# ...

# %%
test_df.iloc[0]['url']
# Out:
# 'https://vfis.tdtu.edu.vn/news/2022-12/lets-raise-your-hands-and-ask-any-questions'
