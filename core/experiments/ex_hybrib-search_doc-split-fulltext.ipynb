# %% [markdown]
# # Experiment
# - Hybrid search
# - Doc split
#
# Reference: https://python.langchain.com/docs/modules/data_connection/retrievers/ensemble

# %%
from langchain.retrievers import BM25Retriever, EnsembleRetriever
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings
from langchain_community.vectorstores import FAISS
import sys
from langchain_core.documents.base import Document

sys.path.append("../")
from src.config import Configuration

from collections import Counter
from langchain.text_splitter import RecursiveCharacterTextSplitter
import pandas as pd

PATH = '../data/test_major'
docs = pd.read_csv(f"{PATH}/docs.csv")
docs = docs[docs['id'] >= 6]
db = []

for i, data in docs.iterrows():
    doc = Document(page_content=data['content'], metadata={"id": data['id']})
    db.append(doc)

print(len(db))
# Out:
# 39

# %% [markdown]
# # Hybrid

# %%
conf = Configuration()

MODEL = "sentence-transformers/LaBSE"
INDEX = "labse-major"

# MODEL = "keepitreal/vietnamese-sbert"
# INDEX = "vnsbert-major"

WEIGHTS = [0.5, 0.5]
K = 2

embeddings = HuggingFaceInferenceAPIEmbeddings(
    api_key=conf.load_hg_token(),
    model_name=MODEL)

# %%
from langchain_community.vectorstores.elasticsearch import ElasticsearchStore
conf = Configuration()
# initialize the bm25 retriever and faiss retriever
bm25_retriever = BM25Retriever.from_documents(db)
bm25_retriever.k = K

elastic_vector_search = ElasticsearchStore(
            es_connection=conf.load_elasticsearch_connection(),
            index_name=INDEX,
            embedding=embeddings,
            distance_strategy="EUCLIDEAN_DISTANCE")

es_retriever = elastic_vector_search.as_retriever(search_kwargs={"k": K})

# initialize the ensemble retriever
ensemble_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever, es_retriever], weights=WEIGHTS
)

# %% [markdown]
# # Test

# %%
# !ls ../data/test_major
# Out:
# docs.csv		    private_test_case.csv
# hard_private_test_case.csv  public_test_case.csv

# %%
PATH = '../data/test_major'

pv_qas = pd.read_csv(f"{PATH}/private_test_case.csv")
qas = pd.read_csv(f"{PATH}/public_test_case.csv")

def test_major(ensemble_retriever, limit):
    correct = 0
    total = 0
    for id, row in qas.iterrows():
        query = row['public question']
        total += 1
        try:
            res = ensemble_retriever.get_relevant_documents(query)
            for idx, r in enumerate(res):
                target_id = res[0].metadata['id']
                if(int(target_id) == int(row['doc_id'])):
                    correct += 1
                    break
                if idx + 1 == limit:
                    break
        except:
            print(query)
    return [correct,total]

def test_major_private(ensemble_retriever, limit):
    correct = 0
    total = 0
    for id, row in pv_qas.iterrows():
        query = row['private question']
        total += 1
        try:
            res = ensemble_retriever.get_relevant_documents(query)
            for idx, r in enumerate(res):
                target_id = res[0].metadata['id']
                if(int(target_id) == int(row['doc_id'])):
                    correct += 1
                    break
                if idx + 1 == limit:
                    break
        except:
            print(query)
    return [correct,total]

# %% [markdown]
# # Benchmark

# %%
def write_info(f):
    f.write(f"->\n")
    f.write(f"Model: {MODEL}\n")
    f.write(f"Technique: {MODEL} + Hybrid (full text at BM25)\n")
    f.write(f"Index: {INDEX}\n")
    f.write(f"Params\nweights: {WEIGHTS}, k: {K}\n")

# %% [markdown]
# ## LaBSE

# %%
# done
with open("./results/labse_major_hybrid_bm25full_public.txt", "a") as f:
    top = 1
    # c, t = test_major(ensemble_retriever, top)
    c, t = [1, 2]
    write_info(f)
    f.write(f"Find Top: {top}\n")
    f.write(f"Correct: {str(c)}\n")
    f.write(f"Total: {str(t)}\n")
    f.write(f"Score: {str(c/t)}\n")

# %%
with open("./results/labse_major_hybrid_bm25full_public.txt", "a") as f:
    top = 2
    c, t = test_major(ensemble_retriever, top)
    # c, t = [1, 2]
    write_info(f)
    f.write(f"Find Top: {top}\n")
    f.write(f"Correct: {str(c)}\n")
    f.write(f"Total: {str(t)}\n")
    f.write(f"Score: {str(c/t)}\n")
# Out:
# 0.7884615384615384

# %%
with open("./results/labse_major_hybrid_bm25full_private.txt", "a") as f:
    top = 1
    c, t = test_major_private(ensemble_retriever, 1)
    # c, t = [1, 2]
    write_info(f)
    f.write(f"Find Top: {top}\n")
    f.write(f"Correct: {str(c)}\n")
    f.write(f"Total: {str(t)}\n")
    f.write(f"Score: {str(c/t)}\n")

# %%
with open("./results/labse_major_hybrid_bm25full_private.txt", "a") as f:
    top = 2
    c, t = test_major_private(ensemble_retriever, top)
    # c, t = [1, 2]
    write_info(f)
    f.write(f"Find Top: {top}\n")
    f.write(f"Correct: {str(c)}\n")
    f.write(f"Total: {str(t)}\n")
    f.write(f"Score: {str(c/t)}\n")

# %% [markdown]
# ## VN SBert

# %%
a = test_major(ensemble_retriever, 1)
a
# Out:
# Ngành bảo hộ lao động là gì?
# Kỹ sư bảo hộ lao động có thể làm việc ở đâu?
# Sinh viên ngành bảo hộ lao động được đào tạo những gì?
# Điểm nổi bật của chương trình đào tạo ngành bảo hộ lao động là gì?
#
#
# Năng lực của kỹ sư bảo hộ lao động sau khi tốt nghiệp là gì?
#
# Công nghệ sinh học là gì?
#
#
# Công nghệ sinh học được ứng dụng trong những lĩnh vực nào?
#
#
# Sau khi tốt nghiệp ngành Công nghệ sinh học, sinh viên có thể làm những công việc gì?
#
#
# Chương trình đào tạo ngành Công nghệ sinh học như thế nào?
#
#
# Cơ hội việc làm ngành Công nghệ sinh học như thế nào?
#
#
# Tại sao nên học ngành Công nghệ sinh học?
#
#
# Công tác xã hội là gì?
#
# Người học ngành Công tác xã hội có thể làm việc ở đâu?
#
# Chương trình đào tạo ngành Công tác xã hội gồm những gì?
#
# Sinh viên ngành Công tác xã hội có được thực hành nhiều không?
#
# Sinh viên ngành Công tác xã hội có cơ hội được tiếp xúc với chuyên gia không?
#
# Dược học là gì?
# Sinh viên ngành Dược học được trang bị những kiến thức và kỹ năng gì?
#
#
# Sinh viên ngành Dược học có thể làm việc ở đâu?
#
#
# Chương trình đào tạo ngành Dược học được thiết kế như thế nào?
#
#
# Cơ hội nghề nghiệp của ngành Dược học như thế nào?
#
#
# Các kỹ năng mềm cần thiết cho sinh viên ngành Dược học là gì?
#
#
# Kế toán, kiểm toán là gì?
#
#
# Vai trò của kế toán, kiểm toán trong nền kinh tế thị trường?
#
#
# Ngành kế toán - kiểm toán đào tạo những gì?
#
#
# Cơ hội việc làm của ngành kế toán - kiểm toán?
#
#
# Chương trình đào tạo ngành kế toán - kiểm toán như thế nào?
#
#
# Cách để học tốt ngành kế toán - kiểm toán?
#
#
# Khoa học máy tính là gì?
# Sau khi tốt nghiệp khoa học máy tính, tôi có thể làm gì?
# Khoa học máy tính học những gì?
# Chương trình đào tạo khoa học máy tính như thế nào?
# Tại sao ngành Khoa học môi trường lại quan trọng?
# Sinh viên ngành Khoa học môi trường có thể làm gì sau khi tốt nghiệp?
# Chương trình đào tạo ngành Khoa học môi trường như thế nào?
# Ngành Kiến trúc là gì?
#
#
# Kiến trúc sư tốt nghiệp Đại học Tôn Đức Thắng có thể làm gì?
#
#
# Chương trình đào tạo ngành Kiến trúc Đại học Tôn Đức Thắng gồm những gì?
#
#
# Kiến thức và kỹ năng nào mà sinh viên ngành Kiến trúc cần có?
#
#
# Sinh viên ngành Kiến trúc có thể làm gì để phát triển khả năng sáng tạo?
#
#
# Kiến trúc sư cần có những phẩm chất gì?
#
#
# Sinh viên ngành Kiến trúc có cơ hội thực tập và học tập trao đổi quốc tế như thế nào?
# Kiến thức và kỹ năng nào mà sinh viên ngành Kiến trúc được trang bị sau khi tốt nghiệp?
# Tại sao ngành kinh doanh quốc tế lại được quan tâm hiện nay?
# Cử nhân kinh doanh quốc tế có thể làm việc ở đâu?
# Cử nhân kinh doanh quốc tế cần có những kỹ năng gì?
# Kỹ thuật cơ điện tử là gì?
#
#
# Sinh viên ngành Kỹ thuật cơ điện tử khi ra trường có thể làm việc ở đâu?
#
#
# Chương trình đào tạo ngành Kỹ thuật cơ điện tử tại TDTU như thế nào?
#
#
# Sinh viên sau tốt nghiệp ngành Kỹ thuật cơ điện tử có những kiến thức và kỹ năng gì?
#
#
# Kỹ thuật hóa học là gì?
#
#
# Kỹ sư hóa học có thể làm gì sau khi tốt nghiệp?
#
#
# Kỹ sư hóa học được đào tạo những gì?
#
#
# Kỹ sư hóa học được thực hành như thế nào?
#
#
# Kỹ sư hóa học cần có những kỹ năng gì?
#
#
# Kỹ thuật phần mềm là gì?
# Cơ hội nghề nghiệp của sinh viên ngành Kỹ thuật phần mềm là gì?
# Kiến thức và kỹ năng mà sinh viên ngành Kỹ thuật phần mềm được trang bị là gì?
# Chương trình đào tạo ngành Kỹ thuật phần mềm như thế nào?
# Ngành Kỹ thuật xây dựng là gì?
#
#
# Kỹ sư tốt nghiệp ngành Kỹ thuật xây dựng có thể làm gì?
#
#
# Sinh viên ngành Kỹ thuật xây dựng được đào tạo những kiến thức và kỹ năng gì?
#
#
# Chương trình đào tạo ngành Kỹ thuật xây dựng được thiết kế như thế nào?
#
#
# Cơ hội nghề nghiệp của ngành Kỹ thuật xây dựng như thế nào?
#
#
# Kỹ thuật xây dựng công trình giao thông là gì?
# Sinh viên ngành Kỹ thuật xây dựng công trình giao thông sau khi tốt nghiệp có thể làm gì?
# Chương trình đào tạo ngành Kỹ thuật xây dựng công trình giao thông như thế nào?
# Sinh viên ngành Kỹ thuật xây dựng công trình giao thông được tham gia những hoạt động gì để tích lũy kinh nghiệm và nâng cao kỹ năng?
# Kỹ thuật điện là ngành học gì?
# Sinh viên ngành Kỹ thuật điện sau khi ra trường có thể làm việc ở đâu?
# Chương trình đào tạo ngành Kỹ thuật điện có những điểm nổi bật gì?
# Sinh viên ngành Kỹ thuật điện cần có những tố chất gì?
# Ngành Kỹ thuật Điện tử - Viễn thông nghiên cứu những gì?
# Chương trình đào tạo ngành Kỹ thuật Điện tử - Viễn thông như thế nào?
# Sinh viên ngành Kỹ thuật Điện tử - Viễn thông được đào tạo như thế nào?
# Sinh viên ngành Kỹ thuật Điện tử - Viễn thông có cơ hội việc làm như thế nào?
# Sinh viên ngành Kỹ thuật Điện tử - Viễn thông cần có những tố chất gì?
# Ngành Kỹ thuật Điện tử - Viễn thông có triển vọng phát triển như thế nào?
# Ngành kỹ thuật điều khiển và tự động hóa là gì?
# Sinh viên ngành Kỹ thuật điều khiển và tự động hóa sau khi ra trường có thể làm gì?
# Chương trình đào tạo ngành Kỹ thuật điều khiển và tự động hóa như thế nào?
# Khả năng nghề nghiệp của sinh viên ngành Kỹ thuật điều khiển và tự động hóa như thế nào?
# Ngành kỹ thuật điều khiển và tự động hóa có cần thiết đối với sự phát triển kinh tế của đất nước hay không?
# Ngành luật học có những tiềm năng phát triển nghề nghiệp nào trong tương lai?
#
# Sinh viên ngành luật có thể làm những công việc gì sau khi ra trường?
#
# Chương trình đào tạo ngành luật của Trường Đại học Tôn Đức Thắng có gì nổi bật?
#
# Kiến thức luật được đào tạo ở trường luật bao gồm những lĩnh vực nào?
#
# Chương trình đào tạo luật có bao gồm thực hành không?
#
# Sinh viên luật được tham gia thực hành nghề nghiệp như thế nào?
#
# Mạng máy tính và truyền thông dữ liệu là gì?
#
#
# Mục tiêu đào tạo của ngành Mạng máy tính và truyền thông dữ liệu là gì?
#
#
# Cơ hội việc làm của ngành Mạng máy tính và truyền thông dữ liệu là gì?
#
#
# Chương trình đào tạo của ngành Mạng máy tính và truyền thông dữ liệu như thế nào?
#
#
# Ngành Mạng máy tính và truyền thông dữ liệu có khó học không?
#
#
# Các công nghệ mạng phổ biến mà sinh viên tốt nghiệp ngành Mạng máy tính và truyền thông dữ liệu cần nắm vững là gì?
#
#
# Ngành Marketing là gì?
#
#
# Ngành Marketing có vai trò gì trong doanh nghiệp?
#
#
# Sau khi học ngành Marketing, sinh viên có thể làm việc ở đâu?
#
#
# Chương trình học ngành Marketing tại trường Đại học Tôn Đức Thắng như thế nào?
#
#
# Sinh viên ngành Marketing cần có những tố chất gì?
#
#
# Ngành Marketing có triển vọng nghề nghiệp như thế nào?
#
#
# Ngành Ngôn ngữ Anh là gì?
#
#
# Cử nhân ngành Ngôn ngữ Anh sau khi tốt nghiệp có thể làm gì?
#
#
# Chương trình đào tạo ngành Ngôn ngữ Anh bao gồm những gì?
#
#
# Cơ hội việc làm của ngành Ngôn ngữ Anh như thế nào?
#
#
# Ưu điểm của ngành Ngôn ngữ Anh là gì?
#
#
# Nhược điểm của ngành Ngôn ngữ Anh là gì?
#
#
# Ngành Ngôn ngữ Trung Quốc học gì?
#
#
# Cử nhân ngành Ngôn ngữ Trung Quốc có thể làm gì?
#
#
# Chương trình đào tạo ngành Ngôn ngữ Trung Quốc tại Đại học Tôn Đức Thắng có gì đặc biệt?
#
#
# Quan hệ lao động là gì?
#
#
# Mục tiêu của ngành quan hệ lao động là gì?
#
#
# Cử nhân quan hệ lao động có thể làm những công việc gì?
#
#
# Chương trình đào tạo ngành quan hệ lao động cung cấp những kiến thức và kỹ năng gì?
#
#
# Ngành quan hệ lao động có triển vọng phát triển như thế nào?
#
#
# Chương trình đào tạo ngành Quan hệ lao động được thiết kế như thế nào?
#
#
# Sinh viên tốt nghiệp ngành Quan hệ lao động có thể làm gì?
#
#
# Chương trình đào tạo ngành Quan hệ lao động có những lợi ích gì cho người học?
#
#
# Chương trình đào tạo ngành Quan hệ lao động phù hợp với những ai?
#
#
# Quản lý thể dục thể thao - Chuyên ngành Golf là gì?
#
#
# Sinh viên tốt nghiệp chuyên ngành Golf có thể làm gì?
#
#
# Sinh viên học chuyên ngành Golf được trang bị những kiến thức và kỹ năng gì?
#
#
# Sinh viên học chuyên ngành Golf được học tập và rèn luyện trong môi trường như thế nào?
#
#
# Sinh viên học chuyên ngành Golf có cơ hội việc làm như thế nào?
#
#
# Sinh viên tốt nghiệp chuyên ngành Golf có thể làm gì để thành công trong nghề?
#
#
#  Chuyên ngành Kinh doanh thể thao và tổ chức sự kiện đào tạo những gì?
#
#  Tại sao nên chọn học chuyên ngành Kinh doanh thể thao và tổ chức sự kiện?
#
#  Sau khi tốt nghiệp chuyên ngành Kinh doanh thể thao và tổ chức sự kiện, sinh viên có thể làm gì?
#
#  Chương trình đào tạo chuyên ngành Kinh doanh thể thao và tổ chức sự kiện có tốt không?
#  TDTU là trường đại học nào?
#
# Chương trình đào tạo ngành Kinh doanh thể thao và tổ chức sự kiện có gì nổi bật?
#
#
# Sinh viên ngành Kinh doanh thể thao và tổ chức sự kiện có cơ hội thực tập tại những doanh nghiệp nào?
#
#
# Nhà trường có hỗ trợ gì cho sinh viên trong quá trình học tập?
#
#
# Chương trình đào tạo ngành Kinh doanh thể thao và tổ chức sự kiện có gì khác biệt với các ngành đào tạo khác?
#
#
# Ngành quản lý xây dựng là gì?
#
#
# Nhu cầu về chuyên gia quản lý xây dựng ở Việt Nam như thế nào?
#
#
# Sinh viên tốt nghiệp ngành Quản lý xây dựng có thể làm gì?
#
#
# Chương trình đào tạo ngành Quản lý xây dựng tại Trường Đại học Tôn Đức Thắng như thế nào?
#
#
# Điểm nổi bật của chương trình đào tạo ngành Quản lý xây dựng tại Trường Đại học Tôn Đức Thắng là gì?
#
#
# Quản trị nguồn nhân lực là gì?
# Cử nhân Quản trị Kinh doanh chuyên ngành Quản trị nguồn lực được trang bị những kiến thức và kỹ năng gì?
# Sinh viên tốt nghiệp ngành Quản trị nguồn nhân lực có thể làm việc ở đâu?
# Chương trình đào tạo ngành Quản trị nguồn nhân lực như thế nào?
# Tại sao nên học ngành Quản trị nguồn nhân lực?
# Ngành Quản trị kinh doanh chuyên ngành Quản trị Nhà hàng và Khách sạn là ngành gì?
# Chương trình đào tạo của ngành Quản trị kinh doanh chuyên ngành Quản trị Nhà hàng và Khách sạn như thế nào?
# Cử nhân Quản trị Kinh doanh chuyên ngành Nhà hàng - Khách sạn khi tốt nghiệp có thể làm việc ở đâu?
# Những tố chất cần có để học ngành Quản trị kinh doanh chuyên ngành Quản trị Nhà hàng và Khách sạn là gì?
# Ngành Tài chính - Ngân hàng là gì?
# Ngành Tài chính - Ngân hàng có những cơ hội nghề nghiệp nào?
# Chương trình đào tạo ngành Tài chính - Ngân hàng như thế nào?
# Ngành thiết kế nội thất là ngành học về cái gì?
# Cử nhân Thiết kế nội thất có thể làm gì?
# Chương trình đào tạo ngành Thiết kế nội thất của Trường Đại học Tôn Đức Thắng gồm những môn học nào?
# Chương trình đào tạo ngành Thiết kế nội thất của Trường Đại học Tôn Đức Thắng chú trọng đến những điểm gì?
# Chương trình đào tạo ngành Thiết kế nội thất của Trường Đại học Tôn Đức Thắng có gì khác biệt?
# 0.0

# %% [markdown]
# # RUN

# %%
query = "Công nghệ thông tin"
results = elasticsearch.similarity_search_with_score(query)
results
# Out:
# [(Document(page_content='Nhà trường đã chủ động triển khai các chương trình hợp tác, liên kết đào tạo với các công ty công nghệ thông tin lớn nhằm hỗ trợ sinh viên về chuyên môn, cũng như tiếp nhận sinh viên thực tập và học tập thực tế tại các công ty, doanh nghiệp. Sinh viên tốt nghiệp ngành Mạng máy tính và truyền thông dữ liệu được đào tạo nắm vững lý thuyết chuyên môn và có khả năng quản lý và vận hành những công nghệ mạng phổ biến như thư tín điện tử, truyền tải tập tin, truyền thông thông tin, hay những công nghệ tiên tiến như điện toán đám mây, tính toán lưới, tính toán di động, xây dựng và vận hành trung tâm dữ liệu, an toàn và bảo mật thông tin, …', metadata={'id': 24.0}),
#   0.4918411),
#  (Document(page_content='Khoa học máy tính là ngành ứng dụng kiến thức về thuật toán, phương pháp tính toán, ngôn ngữ lập trình, phương pháp phân tích và xây dựng hệ thống thông tin, … để giải quyết các vấn đề thuộc lĩnh vực Khoa học máy tính; phát triển các hệ thống phần mềm máy tính, mô hình tính toán thông minh, các ứng dụng trên các nền tảng hiện đại để phục vụ cho nhiệm vụ công nghiệp hoá, hiện đại hoá đất nước trong lĩnh vực chuyển đổi số.\n\nSau khi tốt nghiệp, cử nhân Khoa học máy tính có thể tự tin đảm nhận tốt các vị trí như chuyên viên thiết kế và xây dựng các phần mềm máy tính, ứng dụng cho thiết bị di động, ứng dụng thương mại điện tử trên nền Web, các trò chơi trên máy tính và di động; chuyên viên quản trị và xây dựng các giải pháp đảm bảo an toàn cho các hệ thống máy tính và hệ thống mạng máy tính; chuyên viên lập trình; chuyên viên phát triển hệ thống thông minh; chuyên viên tư vấn, thẩm định và phát triển các dự án, giải pháp công nghệ thông tin; cán bộ chuyên trách tại các cơ quan nhà nước, … hoặc có thể tiếp tục học tập và nghiên cứu ở các bậc học cao hơn.\nKhi lựa chọn ngành học này tại TDTU, học viên được trang bị kiến thức nền tảng của khoa học máy tính và những kiến thức mang tính định hướng theo xu hướng của doanh nghiệp như: lập trình; phân tích và thiết kế thuật toán; xây dựng trang web, trí tuệ nhân tạo, bảo mật và an toàn máy tính … Sinh viên cũng được trang bị các kiến thức nghiệp vụ về tài chính kế toán, quản trị kinh doanh, … nhằm hiểu được nhu cầu của doanh nghiệp trong việc phát triển các hệ thống thông tin. Nhà trường còn chú trọng đầu tư xây dựng các phòng học thực hành với trang thiết bị hiện đại và liên tục cập nhật để phục vụ cho nhu cầu học tập và nghiên cứu của học viên.', metadata={'id': 11.0}),
#   0.48493728),
#  (Document(page_content='Mạng máy tính và truyền thông dữ liệu là ngành học ứng dụng kiến thức về các nguyên lý kết nối máy tính thành mạng; điện toán đám mây, cách thiết kế và xây dựng hệ thống mạng từ nội bộ đến mạng diện rộng có kết nối toàn cầu; nguyên tắc trao đổi thông tin, dữ liệu giữa các thành phần trên mạng; phát triển ứng dụng mạng, phần mềm trên thiết bị di động; … nhằm cung cấp cơ sở hạ tầng và dịch vụ mạng cho các ngành khác vận hành và phát triển.\n\nCử nhân Mạng máy tính và truyền thông dữ liệu sau khi tốt nghiệp tại Trường Đại học Tôn Đức Thắng có thể tự tin ứng tuyển vào các vị trí như: chuyên viên quản trị mạng máy tính và hệ thống, chuyên viên tư vấn hệ thống mạng, lập trình viên tại các công ty phần mềm, chuyên viên thiết kế mạng chuyên nghiệp, chuyên viên phát triển ứng dụng trên di động và mạng không dây, chuyên viên xây dựng và phát triển các ứng dụng truyền thông, … hoặc có thể tiếp tục nghiên cứu và học lên cao học. \nĐến với ngành học này, ngoài những kiến thức nền tảng thuộc lĩnh vực công nghệ thông tin, sinh viên còn được trang bị thêm kiến thức mang tính ứng dụng và liên tục cập nhật xu hướng mới theo nhu cầu phát triển của xã hội. Ngoài ra, Nhà trường còn chú trọng đầu tư xây dựng các phòng thực hành với máy móc hiện đại để phục vụ cho nhu cầu học tập và nghiên cứu của sinh viên.\n\nĐiểm nổi bật của chương trình đào tạo ngành là được xây dựng theo hướng sát với thực tế và mang tính ứng dụng cao. Các học phần được thiết kế theo chuẩn quốc tế và đi từ cấp độ kiến thức nền cơ bản đến cấp độ sinh viên tự mình phân tích, thiết kế và đề xuất giải pháp phát triển mạng máy tính, đáp ứng nhu cầu của một cá nhân hoặc tổ chức.', metadata={'id': 24.0}),
#   0.47783503),
#  (Document(page_content='Sinh viên sau khi tốt nghiệp được trang bị đầy đủ kiến thức và kỹ năng sử dụng thành thạo các phần mềm phục vụ thiết kế; phân tích, tổng hợp và ứng dụng khoa học công nghệ để thực hiện các đồ án thiết kế kiến trúc; vận dụng khả năng tư duy sáng tạo để phác thảo ý tưởng thiết kế ban đầu cho đến triển khai bản vẽ kỹ thuật thi công; hiểu biết căn bản về các giải pháp kết cấu công trình và sử dụng vật liệu xây dựng trong kiến trúc nội – ngoại thất công trình.', metadata={'id': 13.0}),
#   0.46974835)]

# %%
hybrid_es = ElasticsearchStore(embedding=embeddings,
                          es_connection=config.load_elasticsearch_connection(),
                          index_name="test-basic",
                          strategy=ElasticsearchStore.ApproxRetrievalStrategy(hybrid=True)
                         )

# %%
hybrid_es.similarity_search("Tôi muốn học IT")
# Out:
# ---------------------------------------------------------------------------
# AuthorizationException                    Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 hybrid_es.similarity_search("Tôi muốn học IT")
#
# File ~/miniconda3/envs/uni/lib/python3.9/site-packages/langchain_community/vectorstores/elasticsearch.py:624, in ElasticsearchStore.similarity_search(self, query, k, fetch_k, filter, **kwargs)
#     603 def similarity_search(
#     604     self,
#     605     query: str,
#    (...)
#     609     **kwargs: Any,
#     610 ) -> List[Document]:
#     611     """Return Elasticsearch documents most similar to query.
#     612
#     613     Args:
#    (...)
#     621         in descending order of similarity.
#     622     """
# --> 624     results = self._search(
#     625         query=query, k=k, fetch_k=fetch_k, filter=filter, **kwargs
#     626     )
#     627     return [doc for doc, _ in results]
#
# File ~/miniconda3/envs/uni/lib/python3.9/site-packages/langchain_community/vectorstores/elasticsearch.py:782, in ElasticsearchStore._search(self, query, k, query_vector, fetch_k, fields, filter, custom_query, doc_builder, **kwargs)
#     780     logger.debug(f"Calling custom_query, Query body now: {query_body}")
#     781 # Perform the kNN search on the Elasticsearch index and return the results.
# --> 782 response = self.client.search(
#     783     index=self.index_name,
#     784     **query_body,
#     785     size=k,
#     786     source=fields,
#     787 )
#     789 def default_doc_builder(hit: Dict) -> Document:
#     790     return Document(
#     791         page_content=hit["_source"].get(self.query_field, ""),
#     792         metadata=hit["_source"]["metadata"],
#     793     )
#
# File ~/miniconda3/envs/uni/lib/python3.9/site-packages/elasticsearch/_sync/client/utils.py:402, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     399         except KeyError:
#     400             pass
# --> 402 return api(*args, **kwargs)
#
# File ~/miniconda3/envs/uni/lib/python3.9/site-packages/elasticsearch/_sync/client/__init__.py:3733, in Elasticsearch.search(self, index, aggregations, aggs, allow_no_indices, allow_partial_search_results, analyze_wildcard, analyzer, batched_reduce_size, ccs_minimize_roundtrips, collapse, default_operator, df, docvalue_fields, error_trace, expand_wildcards, explain, ext, fields, filter_path, from_, highlight, human, ignore_throttled, ignore_unavailable, indices_boost, knn, lenient, max_concurrent_shard_requests, min_compatible_shard_node, min_score, pit, post_filter, pre_filter_shard_size, preference, pretty, profile, q, query, rank, request_cache, rescore, rest_total_hits_as_int, routing, runtime_mappings, script_fields, scroll, search_after, search_type, seq_no_primary_term, size, slice, sort, source, source_excludes, source_includes, stats, stored_fields, suggest, suggest_field, suggest_mode, suggest_size, suggest_text, terminate_after, timeout, track_scores, track_total_hits, typed_keys, version)
#    3731 if __body is not None:
#    3732     __headers["content-type"] = "application/json"
# -> 3733 return self.perform_request(  # type: ignore[return-value]
#    3734     "POST", __path, params=__query, headers=__headers, body=__body
#    3735 )
#
# File ~/miniconda3/envs/uni/lib/python3.9/site-packages/elasticsearch/_sync/client/_base.py:320, in BaseClient.perform_request(self, method, path, params, headers, body)
#     317         except (ValueError, KeyError, TypeError):
#     318             pass
# --> 320     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     321         message=message, meta=meta, body=resp_body
#     322     )
#     324 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     325 if not self._verified_elasticsearch:
#     326     # If the header is set we mark the server as verified.
#
# AuthorizationException: AuthorizationException(403, 'security_exception', 'current license is non-compliant for [Reciprocal Rank Fusion (RRF)]')
